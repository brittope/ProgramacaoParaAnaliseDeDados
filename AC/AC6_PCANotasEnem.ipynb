# %%
import pandas as pd

# %%
colunas = ["NU_NOTA_MT", "NU_NOTA_CN", "NU_NOTA_LC", "NU_NOTA_CH","NU_NOTA_REDACAO"]

enem_df = pd.read_parquet('../DataFrames/enem-2023.parquet', columns=colunas)
enem_df.dropna(inplace=True)
enem_df.head(10)
# Out:
#     NU_NOTA_MT  NU_NOTA_CN  NU_NOTA_LC  NU_NOTA_CH  NU_NOTA_REDACAO
# 2        363.2       502.0       475.6       498.9            700.0
# 3        466.7       459.0       507.2       508.5            880.0
# 4        338.3       402.5       446.9       379.2            560.0
# 9        680.2       564.7       610.4       630.3            600.0
# 10       736.3       644.9       626.9       620.2            860.0
# 11       691.9       608.2       607.9       667.6            780.0
# 13       548.8       626.5       614.3       604.9            800.0
# 14       404.6       547.2       593.7       623.3            560.0
# 15       415.6       510.8       388.5       313.4            560.0
# 16       437.0       515.7       544.4       553.1            880.0
